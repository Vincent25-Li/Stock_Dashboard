# %% [markdown]
# ### Analy the Category Name in TWSE

# %%
import os
import log
import pickle
import pandas as pd

from pathlib import PurePath
from datetime import datetime, date, timedelta

# %%
# set arguments
base_url = 'https://www.twse.com.tw/exchangeReport/BFIAMU?response=csv&date={}'  # date format: YYYYMMDD
date_format = '%Y%m%d'
start_date = datetime.strptime('20040709', date_format)
end_date = datetime.strptime('20040713', date_format)

data_base_dir = PurePath('data')
category_name_log_path = data_base_dir / 'category_names.p'
category_trading_record_path = data_base_dir / 'category_trading_record.csv'

# %%
try:
    df = pd.read_csv(url, encoding='big5')
except:
    pass
df = pd.read_csv(url, encoding='big5')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-170-1cc61a0edff8> in <module>
#       3 except:
#       4     pass
# ----> 5 df = pd.read_csv(url, encoding='big5')
#
# ...

# %%
# load category names set if exist
if os.path.exists(category_name_log_path):
    with open(category_name_log_path, 'rb') as f:
        category_names_set = pickle.load(f)
else:
    category_names_set = set()

if os.path.exists(category_trading_record_path):
    dfs = [pd.read_csv(category_trading_record_path)]
else:
    dfs = []

while start_date <= end_date:
    url = base_url.format(start_date.strftime(date_format))
    try:
        df = pd.read_csv(url, encoding='big5')
        df_processed = df.index[1:-2].to_frame(index=False, name=df.index[0])
        category_names = df_processed['分類指數名稱'].apply(lambda x: x.strip())
        category_names_set.add(tuple(category_names))
        dfs.append(df_processed)
    except:
        
    
    start_date += timedelta(days=1)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-162-f3f020566d23> in <module>
#      13 while start_date <= end_date:
#      14     url = base_url.format(start_date.strftime(date_format))
# ---> 15     df = pd.read_csv(url, encoding='big5')
#      16     df_processed = df.index[1:-2].to_frame(index=False, name=df.index[0])
#      17     category_names = df_processed['分類指數名稱'].apply(lambda x: x.strip())
#
# ...

# %%
category_names = df_processed['分類指數名稱'].apply(lambda x: x.strip())
category_names_set
# Out:
# {('水泥類',
#   '食品類',
#   '塑膠類',
#   '紡織纖維類',
#   '電機機械類',
#   '電器電纜類',
#   '化學工業類',
#   '玻璃陶瓷類',
#   '造紙類',
#   '鋼鐵類',
#   '橡膠類',
#   '汽車類',
#   '電子類',
#   '營造建材類',
#   '運輸類',
#   '觀光類',
#   '金融保險類',
#   '百貨貿易類',
#   '其它類')}

# %%
df = pd.read_csv(base_url.format(start_date), encoding='big5')
df_processed = df.index[1:-2].to_frame(index=False, name=df.index[0])

category_names = df_processed['分類指數名稱'].apply(lambda x: x.strip())

# %%
def is_start_date_reach_end(start_date, end_date):
    return start_date <= end_date

while is_start_date_reach_end(start_date, end_date):
    start_date += timedelta(days=1)

# %%
datetime.today().strftime(date_format)
# Out:
# '20210911'

# %%
with open(category_name_log_path, 'wb') as f:
    pickle.dump(category_names_set, f)
# Out:
# {('水泥類',
#   '食品類',
#   '塑膠類',
#   '紡織纖維類',
#   '電機機械類',
#   '電器電纜類',
#   '化學工業類',
#   '玻璃陶瓷類',
#   '造紙類',
#   '鋼鐵類',
#   '橡膠類',
#   '汽車類',
#   '電子類',
#   '營造建材類',
#   '運輸類',
#   '觀光類',
#   '金融保險類',
#   '百貨貿易類',
#   '其它類')}

# %%
df_test = df.reset_index()
df_test
# Out:
#                                level_0        level_1         level_2  \
# 0                               分類指數名稱           成交股數            成交金額
# 1                    水泥類                   34,182,000     526,142,000
# 2                    食品類                   15,710,000     160,662,000
# 3                    塑膠類                   65,440,000   1,991,803,000
# 4                      紡織纖維類               35,371,000     339,278,000
# 5                      電機機械類               14,760,000     273,211,000
# 6                      電器電纜類               44,948,000     478,700,000
# 7                      化學工業類               40,874,000     914,251,000
# 8                      玻璃陶瓷類                3,038,000      35,039,000
# 9                    造紙類                   15,129,000     204,148,000
# 10                   鋼鐵類                  216,125,000   4,794,422,000
# 11                   橡膠類                   21,965,000     345,438,000
# ...
